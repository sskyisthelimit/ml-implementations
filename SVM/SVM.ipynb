# %%
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.datasets import load_breast_cancer
from SVM import SVM
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
X, y = load_breast_cancer(return_X_y=True)
y = np.where(y == 0, -1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
sk_model = SVC(kernel='linear')
sk_model.fit(X_train, y_train)
sk_y_pred = sk_model.predict(X_test)

# %%
c_model = SVM(kernel='linear')
c_model.fit(X_train, y_train)
c_y_pred = c_model.predict(X_test)
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -1.0638e+02 -1.0618e+03  6e+03  3e+00  9e-09
#  1: -6.8802e+01 -6.5618e+02  1e+03  4e-01  5e-09
#  2: -5.2760e+01 -3.4184e+02  5e+02  2e-01  4e-09
#  3: -4.2196e+01 -2.1587e+02  3e+02  9e-02  3e-09
#  4: -3.6716e+01 -1.3004e+02  2e+02  4e-02  2e-09
#  5: -3.4750e+01 -7.4550e+01  6e+01  2e-02  2e-09
#  6: -3.3884e+01 -5.6417e+01  3e+01  7e-03  2e-09
#  7: -3.4015e+01 -4.5203e+01  2e+01  3e-03  2e-09
#  8: -3.4253e+01 -3.9532e+01  6e+00  9e-04  2e-09
#  9: -3.4680e+01 -3.7211e+01  3e+00  2e-04  2e-09
# 10: -3.5055e+01 -3.6358e+01  1e+00  9e-05  2e-09
# 11: -3.5220e+01 -3.5869e+01  7e-01  9e-06  2e-09
# 12: -3.5442e+01 -3.5571e+01  1e-01  1e-06  2e-09
# 13: -3.5496e+01 -3.5506e+01  1e-02  1e-07  2e-09
# 14: -3.5500e+01 -3.5500e+01  2e-04  1e-09  2e-09
# 15: -3.5500e+01 -3.5500e+01  2e-06  1e-11  3e-09
# Optimal solution found.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

cfm_SVM = confusion_matrix(y_test, c_y_pred, labels=[-1, 1])
sns.heatmap(cfm_SVM, annot=True, cmap='Blues', fmt='d', ax=axes[0])
axes[0].set_title("SVM confusion matrix")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Actual")

cfm_SVC = confusion_matrix(y_test, sk_y_pred, labels=[-1, 1])
sns.heatmap(cfm_SVC, annot=True, cmap='Blues', fmt='d', ax=axes[1])
axes[1].set_title("SVC confusion matrix")
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("Actual")


plt.tight_layout()
plt.show()
